# %%
from google.cloud import bigquery

client = bigquery.Client()

QUERY = ('SELECT AI_ID, UPRN FROM `rdmfdev.Whale_mockdata_dataset.Whale_AI_mockdata` LIMIT 100')
query_job = client.query(QUERY)  # API request
rows = query_job.result()  # Waits for query to finish

for row in rows:
    print(row)
# Out:
# Row((109883574750268, 950698168954), {'AI_ID': 0, 'UPRN': 1})
# Row((109256760223223, 950320937277), {'AI_ID': 0, 'UPRN': 1})
# Row((109893804250876, 950186421264), {'AI_ID': 0, 'UPRN': 1})
# Row((109805082504690, 950680091532), {'AI_ID': 0, 'UPRN': 1})
# Row((109403802151520, 950396831655), {'AI_ID': 0, 'UPRN': 1})
# Row((109700474983367, 950920499089), {'AI_ID': 0, 'UPRN': 1})
# Row((109817115341891, 950847571385), {'AI_ID': 0, 'UPRN': 1})
# Row((109651285231360, 950795899795), {'AI_ID': 0, 'UPRN': 1})
# Row((109427416638026, 950900820864), {'AI_ID': 0, 'UPRN': 1})
# Row((109450375265473, 950312393216), {'AI_ID': 0, 'UPRN': 1})
# Row((109607631008974, 950376083218), {'AI_ID': 0, 'UPRN': 1})
# Row((109698558782057, 950131015372), {'AI_ID': 0, 'UPRN': 1})
# Row((109435030509467, 950811944455), {'AI_ID': 0, 'UPRN': 1})
# Row((109597840340134, 950717889752), {'AI_ID': 0, 'UPRN': 1})
# Row((109682261967499, 950282054765), {'AI_ID': 0, 'UPRN': 1})
# Row((109038315955622, 950531854388), {'AI_ID': 0, 'UPRN': 1})
# Row((109944783361348, 950935879407), {'AI_ID': 0, 'UPRN': 1})
# Row((109881768372218, 950879172090), {'AI_ID': 0, 'UPRN': 1})
# Row((109269684696741, 950931641740), {'AI_ID': 0, 'UPRN': 1})
# Row((109704907427667, 950581570793), {'AI_ID': 0, 'UPRN': 1})
# Row((109063444034161, 950637478624), {'AI_ID': 0, 'UPRN': 1})
# Row((109317787270162, 950711035014), {'AI_ID': 0, 'UPRN': 1})
# Row((109816696030804, 950730614069), {'AI_ID': 0, 'UPRN': 1})
# Row((109404555572223, 950596377406), {'AI_ID': 0, 'UPRN': 1})
# Row((109413462081415, 950624785787), {'AI_ID': 0, 'UPRN': 1})
# Row((109894844764847, 950032310436), {'AI_ID': 0, 'UPRN': 1})
# Row((109299775357807, 950818323493), {'AI_ID': 0, 'UPRN': 1})
# Row((109956912307930, 950733977259), {'AI_ID': 0, 'UPRN': 1})
# Row((109495834734504, 950820480085), {'AI_ID': 0, 'UPRN': 1})
# Row((109492199276099, 950079985732), {'AI_ID': 0, 'UPRN': 1})
# Row((109986979692372, 950082673322), {'AI_ID': 0, 'UPRN': 1})
# Row((109100213154609, 950345649361), {'AI_ID': 0, 'UPRN': 1})
# Row((109354038981299, 950799747926), {'AI_ID': 0, 'UPRN': 1})
# Row((109497672070293, 950917682347), {'AI_ID': 0, 'UPRN': 1})
# Row((109276660370578, 950580289563), {'AI_ID': 0, 'UPRN': 1})
# Row((109124250816054, 950164633948), {'AI_ID': 0, 'UPRN': 1})
# Row((109016776713293, 950059422365), {'AI_ID': 0, 'UPRN': 1})
# Row((109333428216356, 950073262297), {'AI_ID': 0, 'UPRN': 1})
# Row((109003857374126, 950336033513), {'AI_ID': 0, 'UPRN': 1})
# Row((109442872840721, 950949058913), {'AI_ID': 0, 'UPRN': 1})
# Row((109894515083472, 950187449323), {'AI_ID': 0, 'UPRN': 1})
# Row((109803477898387, 950261376719), {'AI_ID': 0, 'UPRN': 1})
# Row((109713882546572, 950440439076), {'AI_ID': 0, 'UPRN': 1})
# Row((109906955508987, 950958371971), {'AI_ID': 0, 'UPRN': 1})
# Row((109095012230864, 950065119917), {'AI_ID': 0, 'UPRN': 1})
# Row((109024501936914, 950632928097), {'AI_ID': 0, 'UPRN': 1})
# Row((109505635005054, 950049949875), {'AI_ID': 0, 'UPRN': 1})
# Row((109513998914801, 950329170180), {'AI_ID': 0, 'UPRN': 1})
# Row((109110032183177, 950628499850), {'AI_ID': 0, 'UPRN': 1})
# Row((109279936114592, 950449384571), {'AI_ID': 0, 'UPRN': 1})
# Row((109086501462049, 950178981721), {'AI_ID': 0, 'UPRN': 1})
# Row((109572818238555, 950387282822), {'AI_ID': 0, 'UPRN': 1})
# Row((109212147317139, 950228589577), {'AI_ID': 0, 'UPRN': 1})
# Row((109746504619642, 950941645011), {'AI_ID': 0, 'UPRN': 1})
# Row((109764829311959, 950804078315), {'AI_ID': 0, 'UPRN': 1})
# Row((109729633730710, 950046345330), {'AI_ID': 0, 'UPRN': 1})
# Row((109385520581571, 950273987414), {'AI_ID': 0, 'UPRN': 1})
# Row((109246544110611, 950707611040), {'AI_ID': 0, 'UPRN': 1})
# Row((109786805948848, 950469317465), {'AI_ID': 0, 'UPRN': 1})
# Row((109940646618284, 950797483380), {'AI_ID': 0, 'UPRN': 1})
# Row((109781547981944, 950790620548), {'AI_ID': 0, 'UPRN': 1})
# Row((109299408527957, 950487853931), {'AI_ID': 0, 'UPRN': 1})
# Row((109583414473692, 950044997676), {'AI_ID': 0, 'UPRN': 1})
# Row((109948093705091, 950994223848), {'AI_ID': 0, 'UPRN': 1})
# Row((109116944084117, 950525167991), {'AI_ID': 0, 'UPRN': 1})
# Row((109692682146570, 950545115284), {'AI_ID': 0, 'UPRN': 1})
# Row((109539775709276, 950229128254), {'AI_ID': 0, 'UPRN': 1})
# Row((109956910743949, 950844771513), {'AI_ID': 0, 'UPRN': 1})
# Row((109542523412467, 950805514696), {'AI_ID': 0, 'UPRN': 1})
# Row((109997763423875, 950971453835), {'AI_ID': 0, 'UPRN': 1})
# Row((109628249445711, 950107577815), {'AI_ID': 0, 'UPRN': 1})
# Row((109351464688042, 950578149787), {'AI_ID': 0, 'UPRN': 1})
# Row((109932921842122, 950282088118), {'AI_ID': 0, 'UPRN': 1})
# Row((109625473301659, 950894846123), {'AI_ID': 0, 'UPRN': 1})
# Row((109566116970316, 950366544888), {'AI_ID': 0, 'UPRN': 1})
# Row((109642446511954, 950964028780), {'AI_ID': 0, 'UPRN': 1})
# Row((109097154892382, 950604803087), {'AI_ID': 0, 'UPRN': 1})
# Row((109220709512134, 950720870310), {'AI_ID': 0, 'UPRN': 1})
# Row((109306528479428, 950816437037), {'AI_ID': 0, 'UPRN': 1})
# Row((109097278377053, 950864041799), {'AI_ID': 0, 'UPRN': 1})
# Row((109000279403270, 950658556807), {'AI_ID': 0, 'UPRN': 1})
# Row((109480878681015, 950363225055), {'AI_ID': 0, 'UPRN': 1})
# Row((109631761657308, 950724059068), {'AI_ID': 0, 'UPRN': 1})
# Row((109651495717377, 950736638901), {'AI_ID': 0, 'UPRN': 1})
# Row((109915957815198, 950427958186), {'AI_ID': 0, 'UPRN': 1})
# Row((109022185720043, 950505040124), {'AI_ID': 0, 'UPRN': 1})
# Row((109409150613571, 950262189618), {'AI_ID': 0, 'UPRN': 1})
# Row((109873240017617, 950232376073), {'AI_ID': 0, 'UPRN': 1})
# Row((109775581592862, 950845389624), {'AI_ID': 0, 'UPRN': 1})
# Row((109412212640741, 950438909291), {'AI_ID': 0, 'UPRN': 1})
# Row((109004905980414, 950022000457), {'AI_ID': 0, 'UPRN': 1})
# Row((109156717771627, 950825256578), {'AI_ID': 0, 'UPRN': 1})
# Row((109472793688182, 950216254103), {'AI_ID': 0, 'UPRN': 1})
# Row((109194738850987, 950655396923), {'AI_ID': 0, 'UPRN': 1})
# Row((109493946802182, 950638977994), {'AI_ID': 0, 'UPRN': 1})
# Row((109353469069870, 950565168168), {'AI_ID': 0, 'UPRN': 1})
# Row((109539947579996, 950377447972), {'AI_ID': 0, 'UPRN': 1})
# Row((109620400729372, 950960616438), {'AI_ID': 0, 'UPRN': 1})
# Row((109378219974362, 950457079860), {'AI_ID': 0, 'UPRN': 1})
# Row((109618837977690, 950589845349), {'AI_ID': 0, 'UPRN': 1})
